# %%
from openai import OpenAI
OPENROUTER_API_KEY="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"

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=OPENROUTER_API_KEY,
)

completion = client.chat.completions.create(
  extra_headers={
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  model="openai/gpt-4o",
  messages=[
    {
      "role": "user",
      "content": "What is the meaning of life?"
    }
  ]
)

print(completion.choices[0].message.content)
# Out:
# The meaning of life is a question that has been contemplated by philosophers, theologians, and thinkers throughout history, and it doesn't have a definitive answer. Different people and cultures have different interpretations:
#
# 1. **Philosophical Perspective**: Some philosophical viewpoints suggest that life has no inherent meaning, proposing instead that individuals must create their own meaning and purpose through their actions, relationships, and choices.
#
# 2. **Religious Perspective**: Many religions offer specific interpretations of life's meaning, often centered around serving a higher power, achieving spiritual enlightenment, or adhering to moral principles that align with religious teachings.
#
# 3. **Scientific Perspective**: From a scientific or existential perspective, life can be seen as a complex consequence of biological evolution, with meaning being a human construct rather than an objective truth.
#
# 4. **Personal Perspective**: On a personal level, the meaning of life might be found in love, family, personal growth, the pursuit of happiness, and the impact one has on others and the world.
#
# Ultimately, the meaning of life is deeply subjective, and it often reflects a person's beliefs, values, and experiences.
